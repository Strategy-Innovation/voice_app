# %%
import os
import openai
#openai.api_key = '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' # Paid
#openai.api_key = 'qGc1sk-AQoz3EcUXuUk9tOnMcDlT3BlbkFJb0xJL6EYMhFFoCwQCiX5' # Free Trail
openai.api_key='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'  # Free Trail

from flask import Flask
from flask_cors import CORS
#import request
import docx
import time
import nltk
#import azure.cognitiveservices.speech as speechsdk
import time
import re
from nltk.tokenize import word_tokenize, sent_tokenize
from fastapi import FastAPI, File, UploadFile
from fastapi.responses import FileResponse
from fastapi import FastAPI, Request, Form, UploadFile, File
import openpyxl
import uvicorn
#from scipy.io.wavfile import write
#import wavio as wv
#from fuzzywuzzy import process,fuzz
#from pydub import AudioSegment
#import math
app = Flask(__name__)
CORS(app)

from nltk.tokenize import  word_tokenize, sent_tokenize

from fastapi.responses import HTMLResponse
from fastapi.staticfiles import StaticFiles
from fastapi.templating import Jinja2Templates

#API_KEY = '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' 
#content1="Their storage tank farms are very congested. Client do not conduct mock drill. Answer below questions from above information. If answer to any question below is uncertain, please respond Uncertain, otherwise respond Yes or No without ,." 
instruction="If you are not sure about answer to the question, please respond Uncertain, otherwise respond 'Yes' or 'No'"
answer_check = 0
#questions = [     "Does client have fire sprinkler system",     "Does client follow the industry compliances?",  "Are the employees good?" ]

Extra_Question="List down atleast 5 additional questions which can be generated with the following content."
questions = [
    "Does Client XYZ have closed loop feeder system?",
    "Is clients storage facility good?",
    "Does Client have work permit system",
    "Does Client conduct fire mock drill",
    "Does client have firehydrant system",
#     "Does client have fire extinguisher?",
#     "Does client have fire sprinkler system",
#     "Does client follow the industry compliances?",
#     "Are the employees good?"
   # "Does the client have a fire alarm system"
    
    # Add more questions as needed
    ]
def text_conerter(file_path):
    model_id="whisper-1"
    #media_file_path="C:\\Users\\PRV\\Recording.m4a"
    #media_file_path="C:\\Users\\PRV\\Documents\\Sound Recordings\\m_test.m4a"
    media_file_path =file_path
    print(media_file_path)
    media_file=open(media_file_path,"rb")
    response=openai.Audio.transcribe(api_key=openai.api_key, model=model_id,file=media_file)
    content1=response.text + "\n" + str(instruction) + "\n"
    content2=response.text
    return content1,content2

def store_file_get_link(uploaded_file):
    #wv.write(uploaded_file.filename,uploaded_file, 44100, sampwidth=2)
    file_location = os.getcwd()+"\\"+uploaded_file.filename+".m4a"
    print("\nICICI PRRS SYSTEM")
    with open(file_location, "wb+") as file_object:
        file_object.write(uploaded_file.file.read())
    return (file_location)

#content= str(text_conerter()) + "\n" + str(instruction) + "\n"

def get_openai_answer(question, context):
    # Call the OpenAI API to generate an answer
    response = openai.Completion.create(
        engine="text-davinci-003",  # Choose the appropriate engine
        prompt=context + "\nQ: " + question + "\nA:",
        max_tokens=5,  # Adjust the number of tokens as per your needs
        temperature=0.3,  # Adjust the temperature value as per your needs
        n=1,  # Number of responses to generate
        stop=None,  # Stop sequence to limit the response length (optional)
    )    
    # Extract the answer from the API response
    answer = response.choices[0].text.strip().split("\n")[0]
    return answer
def get_openai_answer1(question, context):
    # Call the OpenAI API to generate an answer
    response = openai.Completion.create(
        engine="text-davinci-003",  # Choose the appropriate engine
        prompt=context + "\nQ: " + question + "\nA:",
        max_tokens=50,  # Adjust the number of tokens as per your needs
        temperature=0.3,  # Adjust the temperature value as per your needs
        n=1,  # Number of responses to generate
        stop=None,  # Stop sequence to limit the response length (optional)
    )    
    # Extract the answer from the API response
    response_i = response["choices"][0]["text"]
    response = re.sub(r'\d+\.\s', '', response_i)
    return response

def answer_validation(ans_response,questions,context):
    unanswered_questions=[]
    answered_questions=[]
    answer_responses=ans_response.split(",")
    a=len(questions)
    flag=0
    for question in questions:
       # time.sleep(21)
        answer = get_openai_answer(question, context)
        print(question)
        print(answer)
        if answer=="Uncertain" or answer=="Uncertain." or answer=="Uncertain,":
            unanswered_questions.append(question)
        else:
            answered_questions.append(question)
            answer_responses.append(answer)
            flag=flag+1
    if flag<a:
        return (0,unanswered_questions,answered_questions,answer_responses)
    else:
        return (1,unanswered_questions,answered_questions,answer_responses)
def score_generation(answered_score,questions,context,context1):
    count=0
    score=0
    answered_score=answered_score.split(",")    
    for question in questions:
        #time.sleep(30)
        answer = get_openai_answer(question, context)
        answered_score.append(answer)
        print("Q: " + question)
        print("A: " + answer)
    for answer in answered_score:
        count=count+1
        if answer=="Yes":
            score=score+100
        else:
            score=score+0
    net_score= score/count
    print("Client Score\n")
    print(net_score)
    extra_questions = get_openai_answer1(context1,Extra_Question)
    print("Anoop")
    print(extra_questions)
    extra_questions1=extra_questions.split("\n")
    return(net_score,extra_questions1) 

def corefunction(ans_response,content2,L_content):
    L_questions=content2
    flag,answer_check,answered_questions,answer_responses= answer_validation(ans_response,L_questions,L_content)
    return (flag,answer_check,answered_questions,answer_responses)
    
import nest_asyncio
nest_asyncio.apply()
app=FastAPI()
origins = ["*"]
app.mount("/static", StaticFiles(directory="template1"), name="static")

templates = Jinja2Templates(directory="template1")

@app.get("/basic", response_class=HTMLResponse)
async def get_basic_form(request: Request):
    response = answer_check
    return templates.TemplateResponse("home.html", {"request": request, "response": response})
    #return templates.TemplateResponse("Recorder_edit.html", {"request": request})

@app.post('/api/Append')
async def Click_Here1():
    return({"200 OK"})
    
@app.post('/api/Upload')
async def Click_Here(request: Request, myInput1: str = Form(...), myInput:  str = Form(...), file: UploadFile = File(...)):
    unanswered_questions=myInput
    temp=unanswered_questions
    answered_score=myInput1
    preious_score=answered_score
    print("Check\n")
    print(type(temp))

    print("Check1234\n")
    Wave_Path = store_file_get_link(file)
    if unanswered_questions=="ALL":
        inspection,L_content2=text_conerter(Wave_Path)
        L_content=inspection
        L_questions=questions
        print(type(L_questions))
        answer_check,unanswered_questions,answered_questions,answer_responses= corefunction(answered_score,L_questions,L_content)
        print("Mohit1\n")
        print(answer_check)
        print(answer_responses)
        print("Mohit2\n")
        if answer_check==1:
            score,extra_questions=score_generation(preious_score,L_questions,L_content,L_content2)
            return templates.TemplateResponse("New_App.html", {"request": request, "my_variable": score,"extra_questions": extra_questions})
            # return({"200 OK":score})
        else:
#             import json
#             context = {
#                 'unanswered_questions': json.dumps(unanswered_questions)
#             }
            import json
            return templates.TemplateResponse("New_App.html", {"request": request, "answer_responses":json.dumps(answer_responses),"unanswered":unanswered_questions,"unanswered_question": json.dumps(unanswered_questions)})
           # return({"200 OK":Wave_Path, "Unanswered Question":unanswered_questions, "Answered Question":answered_questions})
    else:
        inspection=text_conerter(Wave_Path)
        L_content=inspection
        L_questions=temp.split(",")
        print("Mohit \n")
        print(temp)
        print("Mohit \n")
        print(L_questions)
        answer_check,unanswered_questions,answered_questions,answer_responses= corefunction(answered_score,L_questions,L_content)
        print("Unanswered QUestion Check \n")
        print(answer_check)
        print("Test Question Check \n")
        print(answered_questions)
        print("Test1 Question Check \n")
        if answer_check==1:
            score,extra_questions=score_generation(preious_score,L_questions,L_content,L_content2)
            print("Check123")
            print(extra_questions)
            return templates.TemplateResponse("New_App.html", { "request": request, "extra_questions": extra_questions, "my_variable": score })
        else:
            import json
            return templates.TemplateResponse("New_App.html", {"request": request, "answer_responses":json.dumps(answer_responses),"unanswered":unanswered_questions,"unanswered_question": json.dumps(unanswered_questions)})
if __name__=="__main__":
        uvicorn.run(app)
# Out:
# INFO:     Started server process [3725]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 48] error while attempting to bind on address ('127.0.0.1', 8000): address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/uvicorn/server.py:160, in Server.startup(self, sockets)
#     159 try:
# --> 160     server = await loop.create_server(
#     161         create_protocol,
#     162         host=config.host,
#     163         port=config.port,
#     164         ssl=config.ssl,
#     165         backlog=config.backlog,
#     166     )
#     167 except OSError as exc:
#
# File ~/anaconda3/lib/python3.11/asyncio/base_events.py:1525, in BaseEventLoop.create_server(self, protocol_factory, host, port, family, flags, sock, backlog, ssl, reuse_address, reuse_port, ssl_handshake_timeout, ssl_shutdown_timeout, start_serving)
#    1524     except OSError as err:
# -> 1525         raise OSError(err.errno, 'error while attempting '
#    1526                       'to bind on address %r: %s'
#    1527                       % (sa, err.strerror.lower())) from None
#    1528 completed = True
#
# OSError: [Errno 48] error while attempting to bind on address ('127.0.0.1', 8000): address already in use
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 232
#     231 if __name__=="__main__":
# --> 232         uvicorn.run(app)
#
# File ~/anaconda3/lib/python3.11/site-packages/uvicorn/main.py:587, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     586 else:
# --> 587     server.run()
#     588 if config.uds and os.path.exists(config.uds):
#
# File ~/anaconda3/lib/python3.11/site-packages/uvicorn/server.py:61, in Server.run(self, sockets)
#      60 self.config.setup_event_loop()
# ---> 61 return asyncio.run(self.serve(sockets=sockets))
#
# File ~/anaconda3/lib/python3.11/site-packages/nest_asyncio.py:35, in _patch_asyncio.<locals>.run(main, debug)
#      34 try:
# ---> 35     return loop.run_until_complete(task)
#      36 finally:
#
# File ~/anaconda3/lib/python3.11/site-packages/nest_asyncio.py:84, in _patch_loop.<locals>.run_until_complete(self, future)
#      83 while not f.done():
# ---> 84     self._run_once()
#      85     if self._stopping:
#
# File ~/anaconda3/lib/python3.11/site-packages/nest_asyncio.py:120, in _patch_loop.<locals>._run_once(self)
#     119     if not handle._cancelled:
# --> 120         handle._run()
#     121 handle = None
#
# File ~/anaconda3/lib/python3.11/asyncio/events.py:80, in Handle._run(self)
#      79 try:
# ---> 80     self._context.run(self._callback, *self._args)
#      81 except (SystemExit, KeyboardInterrupt):
#
# File ~/anaconda3/lib/python3.11/asyncio/tasks.py:350, in Task.__wakeup(self, future)
#     343 else:
#     344     # Don't pass the value of `future.result()` explicitly,
#     345     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)
#     348     # instead of `__next__()`, which is slower for futures
#     349     # that return non-generator iterators from their `__iter__`.
# --> 350     self.__step()
#     351 self = None
#
# File ~/anaconda3/lib/python3.11/site-packages/nest_asyncio.py:196, in _patch_task.<locals>.step(task, exc)
#     195 try:
# --> 196     step_orig(task, exc)
#     197 finally:
#
# File ~/anaconda3/lib/python3.11/asyncio/tasks.py:267, in Task.__step(***failed resolving arguments***)
#     264 if exc is None:
#     265     # We use the `send` method directly, because coroutines
#     266     # don't have `__iter__` and `__next__` methods.
# --> 267     result = coro.send(None)
#     268 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/uvicorn/server.py:78, in Server.serve(self, sockets)
#      76 logger.info(message, process_id, extra={"color_message": color_message})
# ---> 78 await self.startup(sockets=sockets)
#      79 if self.should_exit:
#
# File ~/anaconda3/lib/python3.11/site-packages/uvicorn/server.py:170, in Server.startup(self, sockets)
#     169     await self.lifespan.shutdown()
# --> 170     sys.exit(1)
#     172 assert server.sockets is not None
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2092, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2089 if exception_only:
#    2090     stb = ['An exception has occurred, use %tb to see '
#    2091            'the full traceback.\n']
# -> 2092     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2093                                                      value))
#    2094 else:
#    2095     try:
#    2096         # Exception classes can customise their traceback - we
#    2097         # use this in IPython.parallel for exceptions occurring
#    2098         # in the engines. This should return a list of strings.
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:644, in ListTB.get_exception_only(self, etype, value)
#     636 def get_exception_only(self, etype, value):
#     637     """Only print the exception type and message, without a traceback.
#     638
#     639     Parameters
#    (...)
#     642     value : exception value
#     643     """
# --> 644     return ListTB.structured_traceback(self, etype, value)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:511, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     508     chained_exc_ids.add(id(exception[1]))
#     509     chained_exceptions_tb_offset = 0
#     510     out_list = (
# --> 511         self.structured_traceback(
#     512             etype, evalue, (etb, chained_exc_ids),
#     513             chained_exceptions_tb_offset, context)
#     514         + chained_exception_message
#     515         + out_list)
#     517 return out_list
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1310, in AutoFormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1308 else:
#    1309     self.tb = tb
# -> 1310 return FormattedTB.structured_traceback(
#    1311     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1199, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1196 mode = self.mode
#    1197 if mode in self.verbose_modes:
#    1198     # Verbose modes need a full traceback
# -> 1199     return VerboseTB.structured_traceback(
#    1200         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1201     )
#    1202 elif mode == 'Minimal':
#    1203     return ListTB.get_exception_only(self, etype, value)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1052, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1043 def structured_traceback(
#    1044     self,
#    1045     etype: type,
#    (...)
#    1049     number_of_lines_of_context: int = 5,
#    1050 ):
#    1051     """Return a nice text document describing the traceback."""
# -> 1052     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1053                                                            tb_offset)
#    1055     colors = self.Colors  # just a shorthand + quicker name lookup
#    1056     colorsnormal = colors.Normal  # used a lot
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:953, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#     950 assert isinstance(tb_offset, int)
#     951 head = self.prepare_header(etype, self.long_header)
#     952 records = (
# --> 953     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     954 )
#     956 frames = []
#     957 skipped = 0
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py:1021, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1019 while cf is not None:
#    1020     try:
# -> 1021         source_file = inspect.getsourcefile(etb.tb_frame)
#    1022         lines, first = inspect.getsourcelines(etb.tb_frame)
#    1023     except OSError:
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
