# %%
import openai
import pandas as pd
openai.api_key = "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"
#Claim_question="Based on the below "Claims_summery" explaining the reason for a the fire incident. Please generate the questions which can be formed from the content shared above which can help me assess the likelihood of the risk occuring in the future"
#Claims_summery="AutomotiveThe packaging stores was installed with light fittings, wiring and electric switch board. On enquiring from the insured’s representatives, it came to notice that, lights in the store normally remain in ‘switch on’ mode during the working hours. Thus all the electric wires, switches & fittings were energized at the time of fire. In our opinion, there could be electric short circuiting somewhere in electric wires and/or fittings and sparks of which could have fallen on the combustible materials such as cardboard boxes, cartons etc., which could have caught fire instantly and then the fire spread further to other contents. Thus, the fire/flames so originated spread further and extensively burnt & damaged insured’s assets, stocks etc."

# def generate_question(summary):
#     prompt = f"{summary}"
#     response = openai.Completion.create(
#         engine="text-davinci-002",
#         prompt=prompt,
#         temperature=0.7,
#         max_tokens=300,
#     )
#     question = response['choices'][0]['text'].strip()
#     return question

def generate_question_from_summary(summary):
    prompt = f"Based on the below explaining the reason for a the fire incident. Please generate the questions which can be formed from the content shared which can help me assess the likelihood of the risk occuring in the future from the summary, pleaese generate the questions which can be answered as Yes or No kind of response:\n{summary}"
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        temperature=0.2,
        max_tokens=350,
    )
    question = response['choices'][0]['text'].strip()
    return question

def modify_question(question):
    modified_question = f"{question}\n"
    return modified_question
summery=0
def main():
    # Replace 'path_to_your_file.xlsx' with the actual file path
    file_path = "PRRS_Claims_Data.xlsx"
    sheet_name = 'Sheet1'
    summary_column = 'Loss_Remarks'
    target_columns = 'Industry_Type'
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    
    # Generate questions for each summary and target column
#     for _, row in df.iterrows():
# def process_dataframe(df, summary_column, target_columns):
    for _, row in df.iterrows():
        summary = row[summary_column]
        occupancy=row[target_columns]
        print(occupancy)
        print("Summary\n:", summary)
        if occupancy=="Automotive":
            question =generate_question_from_summary(summary)
            print(question)
#         for Col in occupancy:
# #             question = generate_question_from_summary(summary, Col, occupancy)
#             modified_question = modify_question(question)
#             print(f"\nGenerated Question for {Col}:\n", modified_question)

#         questions = generate_question(summary)
#         modified_questions = modify_question(questions)
        print("\n")

# Replace 'target_columns' with the actual list of column names you want to use as target_columns

# file_path = r"/Users/strategy_innovation/Downloads/Data/PRRS_Claims_Data.xlsx"
# sheet_name = 'Sheet1'
# df = pd.read_excel(file_path, sheet_name=sheet_name)
# summary_column = 'Loss_Remarks'
# target_columns = 'Industry_Type'
# process_dataframe(df, summary_column, target_columns)

if __name__ == "__main__":
    main()
# Out:
# Automotive
# Summary
# : The packaging stores was installed with light fittings, wiring and electric switch board. On enquiring from the insured’s
# representatives, it came to notice that, lights in the store normally remain in ‘switch on’ mode during the working hours. Thus all the electric wires, switches & fittings were energized at the time of fire. In our opinion, there could be electric short circuiting
# somewhere in electric wires and/or fittings and sparks of which could have fallen on the combustible materials such as cardboard boxes, cartons etc., which could have caught fire instantly and then the fire spread further to other contents. Thus, the fire/flames so
# originated spread further and extensively burnt & damaged insured’s assets, stocks etc.
# 1. Did the packaging store have light fittings, wiring and electric switch board installed?
# 2. Did the representatives state that the lights in the store normally remain in the 'switch on' mode during working hours?
# ...
